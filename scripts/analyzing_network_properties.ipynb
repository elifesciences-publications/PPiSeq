# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.axes as axs
import os
import re

# %%
dict_of_nets = dict()
for each_path in os.listdir("../tmp/"):
    if re.search("_mean.nxp",each_path):
        dict_of_nets[re.sub("_mean.nxp","",each_path)] = nx.read_gpickle(os.path.join("../tmp/",each_path))

# %%
for net_name,net in dict_of_nets.items():
    de = [ i[1] for i in net.degree()]
    
    degree_hist = plt.figure()
    plt.hist(de)
    #plt.semilogx()
    plt.title(net_name+": barplot of node degrees")
    plt.ylabel("Count of nodes")
    plt.xlabel("Degree of node")
    degree_hist.show()
    
    pos = nx.layout.spring_layout(net)
    
    node_sizes = np.sqrt(de)
    line_widths = [ float(net.get_edge_data(u,v)['fitness']) for u,v in net.edges() ]
    plt.figure(figsize=(32, 32))
    nodes = nx.draw_networkx_nodes(net, pos, node_size=node_sizes, node_color='blue')
    edges = nx.draw_networkx_edges(net, pos, node_size=node_sizes, width=line_widths, alpha=0.5)
    plt.title(net_name+": net of all connections")
    plt.savefig("../tmp/"+net_name+"_hairball.svg")
    plt.show()

# %%
dc = list(nx.degree_centrality(g_dmso).values())

# %%
degree_centrality_hist = plt.figure()
plt.hist(dc)
#plt.semilogx()
plt.title("Barplot of node degrees")
plt.ylabel("Count of nodes")
plt.xlabel("Degree of node")
degree_centrality_hist.show()
degree_centrality_hist.savefig("../tmp/DMSO_summary_degreecentrality_barplot.png")

# %%
bc = list(nx.betweenness_centrality(g_dmso).values())

# %%
betweenness_centrality_hist = plt.figure()
plt.hist(bc)
#plt.semilogx()
plt.title("Barplot of node degrees")
plt.ylabel("Count of nodes")
plt.xlabel("Degree of node")
betweenness_centrality_hist.show()
betweenness_centrality_hist.savefig("../tmp/DMSO_summary_betweennesscentrality_barplot.png")

# %%
ebc = list(nx.edge_betweenness_centrality(g_dmso).values())

# %%
edge_betweenness_centrality_hist = plt.figure()
plt.hist(ebc)
#plt.semilogx()
plt.title("Barplot of node degrees")
plt.ylabel("Count of nodes")
plt.xlabel("Degree of node")
edge_betweenness_centrality_hist.show()
edge_betweenness_centrality_hist.savefig("../tmp/DMSO_summary_edgebetweennesscentrality_barplot.png")

# %%
ec = list(nx.eigenvector_centrality(g_dmso).values())

# %%
eigenvector_centrality_hist = plt.figure()
plt.hist(ec)
#plt.semilogx()
plt.title("Barplot of node degrees")
plt.ylabel("Count of nodes")
plt.xlabel("Degree of node")
eigenvector_centrality_hist.show()
eigenvector_centrality_hist.savefig("../tmp/DMSO_summary_eigenvectorcentrality_barplot.png")
