# %%
import Match_cluster_known_barcodes_levenshtein_update
from Match_cluster_known_barcodes_levenshtein_update import pairwise_mismatch

# %%
directory = "/Volumes/Y/X/Zhimin/PPiSeq/HU/HU_all_lintag/" # Directory to the merged barcodes
cluster_threshold = 2 # only take the cluster with counts larger than threshold
known_barcodes_1 ='/Volumes/Y/X/Zhimin/PPiSeq/DMSO/all_lintag_files_final/PPI_barcodes/protein_barcodes_first.csv' # Known barcode_1
known_barcodes_2 ='/Volumes/Y/X/Zhimin/PPiSeq/DMSO/all_lintag_files_final/PPI_barcodes/protein_barcodes_second.csv' # Known barcode_2
old_index_1 = '/Volumes/Y/X/Zhimin/PPiSeq/H2O2/counts/Unmatched_barcodes_protein_index_01.csv' # Previous mapping information. Since we use the same PPiSeq library, instead of building new map for each environment, we can update the previous map. 
old_index_2 = '/Volumes/Y/X/Zhimin/PPiSeq/H2O2/counts/Unmatched_barcodes_protein_index_02.csv' # Previous mapping information
old_BC1_cluster = '/Volumes/Y/X/Zhimin/PPiSeq/H2O2/counts/H2O2_all_BC1_cluster.csv' # Previous clusters generated by Bartender
old_BC2_cluster = '/Volumes/Y/X/Zhimin/PPiSeq/H2O2/counts/H2O2_all_BC2_cluster.csv' # Previous clusters generated by Bartender
unmatched_lintag1 = 'HU_G0_AGTGATGATCTG_lintag1.txt' # G0 barcode extracted from forward reads (BC.py)
unmatched_lintag2 = 'HU_G0_AGTGATGATCTG_lintag2.txt' # G0 Barcode extracted from reverse reads (BC.py)
unmatched_seqtag = 'HU_G0_AGTGATGATCTG_seqtag.txt'# G0 UMI extract from both forward and reverse reads (BC.py)
bartender_BC1_barcode = 'HU_all_BC1_barcode.csv'# Mapping information of forward reads to clusters (Bartender) in Hydroxyurea
bartender_BC2_barcode = 'HU_all_BC2_barcode.csv' # Mapping information of reverse reads to clusters (Bartender) in Hydroxyurea
bartender_BC1_cluster = 'HU_all_BC1_cluster.csv' # Cluster centroid of forwad reads (Bartender) in Hydroxyurea
bartender_BC2_cluster = 'HU_all_BC2_cluster.csv'# Cluster centroid of reverse reads (Bartender) in Hydroxyurea
output= "HU_G0_all_PPIcounts.csv"
index_construct = 1 # build the mapping information between each read and the known barcodes. Once built can be used for other time points.

# %%
pairwise_mismatch(directory,
                  cluster_threshold, # only take the cluster with counts larger than threshol
                  known_barcodes_1,
                      known_barcodes_2,
                      old_index_1,
                      old_index_2,
                      old_BC1_cluster,
                      old_BC2_cluster,
                      unmatched_lintag1,
                      unmatched_lintag2,
                      unmatched_seqtag,
                      bartender_BC1_barcode,
                      bartender_BC2_barcode,
                      bartender_BC1_cluster,
                      bartender_BC2_cluster,
                      output,
                      index_construct)
# Out:
# First barcodes
# Tue Nov 20 16:46:08 2018
# Tue Nov 20 16:46:08 2018
# Finish 0 of 59212 iterations; 0 match
# Tue Nov 20 16:46:09 2018
# Finish 100 of 59212 iterations; 61 match
# Tue Nov 20 16:47:54 2018
# Finish 200 of 59212 iterations; 110 match
# Tue Nov 20 16:49:42 2018
# Finish 300 of 59212 iterations; 130 match
# Tue Nov 20 16:51:31 2018
# Finish 400 of 59212 iterations; 179 match
# Tue Nov 20 16:53:21 2018
# Finish 500 of 59212 iterations; 213 match
# Tue Nov 20 16:55:10 2018
# Finish 600 of 59212 iterations; 267 match
# Tue Nov 20 16:56:58 2018
# Finish 700 of 59212 iterations; 331 match
# Tue Nov 20 16:58:45 2018
# Finish 800 of 59212 iterations; 392 match
# Tue Nov 20 17:00:33 2018
# Finish 900 of 59212 iterations; 459 match
# Tue Nov 20 17:02:20 2018
# Finish 1000 of 59212 iterations; 539 match
# Tue Nov 20 17:04:07 2018
# Finish 1100 of 59212 iterations; 614 match
# Tue Nov 20 17:05:54 2018
# Finish 1200 of 59212 iterations; 702 match
# Tue Nov 20 17:07:41 2018
# ...

# %%
### Count the double barcodes at G6
unmatched_lintag1 = 'HU_G6_CGCATACACCGA_lintag1.txt'
unmatched_lintag2 = 'HU_G6_CGCATACACCGA_lintag2.txt'
unmatched_seqtag = 'HU_G6_CGCATACACCGA_seqtag.txt'
output= "HU_G6_all_PPIcounts.csv"
index_construct = 0 # No need to build the mapping information (very time-consuming)

# %%
pairwise_mismatch(directory,
                  cluster_threshold, # only take the cluster with counts larger than threshol
                  known_barcodes_1,
                      known_barcodes_2,
                      old_index_1,
                      old_index_2,
                      old_BC1_cluster,
                      old_BC2_cluster,
                      unmatched_lintag1,
                      unmatched_lintag2,
                      unmatched_seqtag,
                      bartender_BC1_barcode,
                      bartender_BC2_barcode,
                      bartender_BC1_cluster,
                      bartender_BC2_cluster,
                      output,
                      index_construct)
# Out:
# 13855 all possible matches
# Remove 0 of unamtched barcodes which have been matched to multiple known barcodes
# 0 duplicated known barcodes
# 13855 unique matches
# 20989 all possible matches
# Remove 0 of unamtched barcodes which have been matched to multiple known barcodes
# 0 duplicated known barcodes
# 20989 unique matches

# %%
### Count the double barcodes at G9
unmatched_lintag1 = 'HU_G9_CAAGAAAGGGTT_lintag1.txt'
unmatched_lintag2 = 'HU_G9_CAAGAAAGGGTT_lintag2.txt'
unmatched_seqtag = 'HU_G9_CAAGAAAGGGTT_seqtag.txt'
output= "HU_G9_all_PPIcounts.csv"
index_construct = 0 # No need to build the mapping information (very time-consuming)

# %%
pairwise_mismatch(directory,
                  cluster_threshold, # only take the cluster with counts larger than threshol
                  known_barcodes_1,
                      known_barcodes_2,
                      old_index_1,
                      old_index_2,
                      old_BC1_cluster,
                      old_BC2_cluster,
                      unmatched_lintag1,
                      unmatched_lintag2,
                      unmatched_seqtag,
                      bartender_BC1_barcode,
                      bartender_BC2_barcode,
                      bartender_BC1_cluster,
                      bartender_BC2_cluster,
                      output,
                      index_construct)
# Out:
# 13855 all possible matches
# Remove 0 of unamtched barcodes which have been matched to multiple known barcodes
# 0 duplicated known barcodes
# 13855 unique matches
# 20989 all possible matches
# Remove 0 of unamtched barcodes which have been matched to multiple known barcodes
# 0 duplicated known barcodes
# 20989 unique matches

# %%
### Count the double barcodes at G9
unmatched_lintag1 = 'HU_G12_CATAGGGTATTG_lintag1.txt'
unmatched_lintag2 = 'HU_G12_CATAGGGTATTG_lintag2.txt'
unmatched_seqtag = 'HU_G12_CATAGGGTATTG_seqtag.txt'
output= "HU_G12_all_PPIcounts.csv"
index_construct = 0 # No need to build the mapping information (very time-consuming)

# %%
pairwise_mismatch(directory,
                  cluster_threshold, # only take the cluster with counts larger than threshol
                  known_barcodes_1,
                      known_barcodes_2,
                      old_index_1,
                      old_index_2,
                      old_BC1_cluster,
                      old_BC2_cluster,
                      unmatched_lintag1,
                      unmatched_lintag2,
                      unmatched_seqtag,
                      bartender_BC1_barcode,
                      bartender_BC2_barcode,
                      bartender_BC1_cluster,
                      bartender_BC2_cluster,
                      output,
                      index_construct)
# Out:
# 13855 all possible matches
# Remove 0 of unamtched barcodes which have been matched to multiple known barcodes
# 0 duplicated known barcodes
# 13855 unique matches
# 20989 all possible matches
# Remove 0 of unamtched barcodes which have been matched to multiple known barcodes
# 0 duplicated known barcodes
# 20989 unique matches
